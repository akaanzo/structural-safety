# %% [markdown]
# # Columns Static Solution - Loads Combos
# ## *Matteo Franzoi* - Anno Accademico 2019/2020
# ### matricola 166788 (triennale)
# ---

# %%
    import math
#import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sympy import *
from sympy import MatrixSymbol, Matrix
import numpy as np
from engineering_notation import EngNumber
from decimal import Decimal
import pandas as pd

# %%
2.75+3.5+3.1+3.1-(.04+.16+.05)
# Out:
# 12.2

# %%
3.1-(.04+.16+.05)
# Out:
# 2.85

# %%
25*.3*.3*12.2
# Out:
# 27.45

# %% [markdown]
# ---
# ## P27
# ### SLU

# %%
N1max_slu = 1.3*(4*21.15+27.45+101.52+90.24+101.536+99.50)+1.5*(80.09+130.284+146.59+127.68)+1.5*(.6*67.96+0*14.1+.7*56.40+.7*95.17+110.54+.6*3.9)
N1max_slu
# Out:
# 1772.8983

# %%
N1min_slu = 1.0*(4*21.15+27.45+101.52+90.24+101.536+99.50)+.8*(80.09+130.284+146.59+127.68)+0*(67.96+0*14.1+.7*56.40+.7*95.17+.7*110.54)-1.5*3.9
N1min_slu
# Out:
# 886.7112000000001

# %%
l1 = 3.1 - .04 - .16 - .05
l2 = 3.1 
l3 = 3.5
l4 = 2.75

# %%
s = np.array([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])

# %%
NG1 = np.array([101.52+21.15, 101.52+21.15+90.24+21.15+25*.3**2 * l1, 101.52+3*21.15+90.24+25*.3**2 * (l1+l2) +101.536, 101.52+4*21.15+90.24+25*.3**2 * (l1+l2+l3) +101.536 + 99.50,  101.52+4*21.15+90.24+25*.3**2 * (l1+l2+l3+l4) +101.536 + 99.50])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NG1,s,12.2, color='#0f0f0f80')
# plt.fill_between(NG1,12.2,s, color='#0f0f0f80')
# plt.xlim(122, 507)
# plt.ylim(0, l1+l2+l3+l4)
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NG1(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NG1', fontsize='22')
# plt.show()

# %%
NG2 = np.array([80.09, 80.09+130.284, 80.09+130.284+146.59, 80.09+130.284+146.59 + 127.68, 80.09+130.284+146.59 + 127.68])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NG2,s,12.2, color='#0f0f0f80')
# plt.fill_between(NG2,12.2,s, color='#0f0f0f80')
# plt.ylim(0, l1+l2+l3+l4)
# plt.xlim(np.min(NG2), np.max(NG2))
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NG2(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NG2', fontsize='22')
# plt.show()

# %%
NQ = np.array([.6*67.96+0*14.1+.6*3.9, .6*67.96+0*14.1+.6*3.9, .6*67.96+0*14.1+.7*56.40+.6*3.9, .6*67.96+0*14.1+.7*56.40+.7*95.17+.6*3.9, .6*67.96+0*14.1+.7*56.40+.7*95.17+110.54+.6*3.9])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NQ,s,12.2, color='#0f0f0f80')
# plt.fill_between(NQ,12.2,s, color='#0f0f0f80')
# plt.ylim(0, l1+l2+l3+l4)
# plt.xlim(np.min(NQ), np.max(NQ))
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NQ(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NQ', fontsize='22')
# plt.show()

# %%
N1max_slu = 1.3*NG1 + 1.5*NG2 + 1.5*NQ
N1max_slu
# Out:
# array([ 344.28   ,  692.84925, 1140.51355, 1599.04455, 1772.8983 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_slu), np.max(N1max_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_slu[0]),float(N1max_slu[1]),float(N1max_slu[2]), float(N1max_slu[3]), float(N1max_slu[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_slu.jpg')
plt.show()

# %%
N1min_slu = 1*NG1 + .8*NG2 + 0*NQ - 1.5*3.9
print(N1min_slu)
# Out:
# [180.892  402.9217 649.8547 880.5237 886.7112]

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_slu), np.max(N1min_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_slu[0]),float(N1min_slu[1]),float(N1min_slu[2]), float(N1min_slu[4])])
plt.axhline(0, color='black')
plt.title('Aione assiale minima (di compressione) sul pilastro P27\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_slu.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE RARA

# %%
N1max_sleRara = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(.6*67.96+0*14.1+.7*56.40+.7*95.17+110.54+.6*3.9)
N1max_sleRara
# Out:
# 1249.245

# %%
N1max_sleRara = NG1 + NG2 + NQ
N1max_sleRara
# Out:
# array([ 245.876 ,  493.9625,  809.6935, 1132.5175, 1249.245 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_sleRara), np.max(N1max_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_sleRara[0]),float(N1max_sleRara[1]),float(N1max_sleRara[2]), float(N1max_sleRara[3]), float(N1max_sleRara[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_sleRara.jpg')
plt.show()

# %%
N1min_sleRara = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(.6*67.96+0*14.1+.7*56.40+.7*95.17+.7*110.54+3.9)
N1min_sleRara
# Out:
# 1217.643

# %%
N1min_sleRara = NG1 + NG2 + np.array([.6*67.96+0*14.1+3.9, .6*67.96+0*14.1+3.9, .6*67.96+0*14.1+.7*56.40+3.9, .6*67.96+0*14.1+.7*56.40+.7*95.17+3.9, .6*67.96+0*14.1+.7*56.40+.7*95.17+.7*110.54+3.9])
N1min_sleRara
# Out:
# array([ 247.436 ,  495.5225,  811.2535, 1134.0775, 1217.643 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_sleRara), np.max(N1min_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_sleRara[0]),float(N1min_sleRara[1]),float(N1min_sleRara[2]), float(N1min_sleRara[3]), float(N1min_sleRara[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P27\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_sleRara.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE FREQUENTE

# %%
N1max_sleFreq = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(.2*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9)
N1max_sleFreq
# Out:
# 1114.877

# %%
N1max_sleFreq = NG1 + NG2 + np.array([0.2*67.96+0*14.1+0*3.9, 0.2*67.96+0*14.1+0*3.9, 0.2*67.96+0*14.1+.3*56.40+0*3.9, 0.2*67.96+0*14.1+.3*56.40+.3*95.17+0*3.9, 0.2*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9])
np.max(N1max_sleFreq)
# Out:
# 1114.877

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_sleFreq), np.max(N1max_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_sleFreq[0]),float(N1max_sleFreq[1]),float(N1max_sleFreq[2]), float(N1max_sleFreq[3]), float(N1max_sleFreq[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_sleFreq.jpg')
plt.show()

# %%
N1min_sleFreq = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9)
N1min_sleFreq
# Out:
# 1101.285

# %%
N1min_sleFreq = NG1 + NG2 + np.array([0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+.3*56.40+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9])
N1min_sleFreq
# Out:
# array([ 202.76  ,  450.8465,  744.0175, 1028.7735, 1101.285 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_sleFreq), np.max(N1min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_sleFreq[0]),float(N1min_sleFreq[1]),float(N1min_sleFreq[2]), float(N1min_sleFreq[3]), float(N1min_sleFreq[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P27\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_sleFreq.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE QUASI PERMANENTE

# %%
N1_sleQP = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9)
N1_sleQP
# Out:
# 1101.285

# %%
N1_sleQP = NG1 + NG2 +  np.array([0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+.3*56.40+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9])
np.max(N1_sleQP)
# Out:
# 1101.285

# %%
plt.figure(figsize=(20,10))
plt.plot(N1_sleQP,s,12.2, color='#0f0f0f80')
plt.fill_between(N1_sleQP,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1_sleQP), np.max(N1_sleQP))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1_sleQP[0]),float(N1_sleQP[1]),float(N1_sleQP[2]), float(N1_sleQP[3]), float(N1_sleQP[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale (di compressione) sul pilastro P27\nCombinazione SLE QUASI PERMANENTE', fontsize='22')
plt.savefig('export/img/P27_axialLoad_sleQP.jpg')
plt.show()

# %% [markdown]
# ---
# ## P36
# ### SLU

# %%
N2max_slu = 1.3*(27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+1.5*(11.36+18.48+91.476+46.2)+1.5*(.5*9.64+0*2+.7*8+59.40+.7*40+.6*.552)
N2max_slu
# Out:
# 715.2263

# %%
NG1 = np.array([14.4+15, 14.4+15+12.8+15+25*.3**2 * l1, 14.4+15+12.8+15+63.36+33.375+25*.3**2 * (l1+l2), 14.4+15+12.8+15+63.36+33.375+36+26.25+25*.3**2 * (l1+l2+l3),  14.4+15+12.8+15+63.36+33.375+36+26.25+25*.3**2 * (l1+l2+l3+l4)])

NG2 = np.array([11.36, 11.36+18.48, 11.36+18.48+91.476, 11.36+18.48+91.476+46.2, 11.36+18.48+91.476+46.2])

NQ = np.array([.5*9.64+0*2+.6*.552, .5*9.64+0*2+.6*.552+.7*8, .5*9.64+0*2+.6*.552+.7*8+59.4, .5*9.64+0*2+.6*.552+.7*8+59.4+.7*40, .5*9.64+0*2+.6*.552+.7*8+59.4+.7*40])

# %%
N2max_slu = 1.3*NG1 + 1.5*NG2 + 1.5*NQ
N2max_slu
# Out:
# array([ 62.9868 , 143.58305, 504.72005, 707.18255, 715.2263 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_slu), np.max(N2max_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_slu[0]),float(N2max_slu[1]),float(N2max_slu[2]), float(N2max_slu[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_slu.jpg')
plt.show()

# %%
N2min_slu = 1*NG1 + 0.8*NG2 + 0*NQ -1.5*.552
N2min_slu
# Out:
# array([ 37.66  ,  86.6565, 263.5473, 370.6323, 376.8198])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_slu), np.max(N2min_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_slu[0]),float(N2min_slu[1]),float(N2min_slu[2]), float(N2min_slu[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_slu.jpg')
plt.show()

# %% [markdown]
# ### SLE RARA

# %%
N2max_sleRara = (27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+(11.36+18.48+91.476+46.2)+(.5*9.64+0*2+.7*8+59.40+.7*40+.6*.552)
N2max_sleRara
# Out:
# 509.30219999999997

# %%
NG1 = np.array([14.4+15, 14.4+15+12.8+15+25*.3**2 * l1, 14.4+15+12.8+15+63.36+33.375+25*.3**2 * (l1+l2), 14.4+15+12.8+15+63.36+33.375+36+26.25+25*.3**2 * (l1+l2+l3),  14.4+15+12.8+15+63.36+33.375+36+26.25+25*.3**2 * (l1+l2+l3+l4)])

NG2 = np.array([11.36, 11.36+18.48, 11.36+18.48+91.476, 11.36+18.48+91.476+46.2, 11.36+18.48+91.476+46.2])

NQ = np.array([.5*9.64+0*2+.6*.552, .5*9.64+0*2+.6*.552+.7*8, .5*9.64+0*2+.6*.552+.7*8+59.4, .5*9.64+0*2+.6*.552+.7*8+59.4+.7*40, .5*9.64+0*2+.6*.552+.7*8+59.4+.7*40])

# %%
N2max_sleRara = NG1 + NG2 + NQ
N2max_sleRara
# Out:
# array([ 45.9112, 104.2037, 358.7897, 503.1147, 509.3022])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_sleRara), np.max(N2max_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_sleRara[0]),float(N2max_sleRara[1]),float(N2max_sleRara[2]), float(N2max_sleRara[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_sleRara.jpg')
plt.show()

# %%
N2min_sleRara = (27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+(11.36+18.48+91.476+46.2)+(.5*9.64+0*2+.7*8+.7*59.40+.7*40+.552)
N2min_sleRara
# Out:
# 491.70300000000003

# %%
N2min_sleRara = NG1 + NG2 + np.array([.5*9.64 + 0*2 + .552, .5*9.64 + 0*2 + .552 + .7*8, .5*9.64 + 0*2 + .552 + .7*8 + .7*59.40, .5*9.64 + 0*2 + .552 + .7*8 + .7*59.40 + .7*40, .5*9.64 + 0*2 + .552 + .7*8 + .7*59.40 + .7*40])
N2min_sleRara
# Out:
# array([ 46.132 , 104.4245, 341.1905, 485.5155, 491.703 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_sleRara), np.max(N2min_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_sleRara[0]),float(N2min_sleRara[1]),float(N2min_sleRara[2]),float(N2min_sleRara[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_sleRara.jpg')
plt.show()

# %% [markdown]
# ### SLE FREQUENTE

# %%
N2max_sleFreq = (27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+(11.36+18.48+91.476+46.2)+(0*9.64+0*2+.3*8+.5*59.40+.6*40+0*.552)
N2max_sleFreq
# Out:
# 467.25100000000003

# %%
N2max_sleFreq = NG1 + NG2 + np.array([0*.9 + 0*.2 + 0*.552, 0*.9 + 0*.2 + 0*.552 + .3*8, 0*.9 + 0*.2 + 0*.552 + .3*8 + .5*59.4, 0*.9 + 0*.2 + 0*.552 + .3*8 + .5*59.4 + .6*40, 0*.9 + 0*.2 + 0*.552 + .3*8 + .5*59.4 + .6*40]) 
N2max_sleFreq
# Out:
# array([ 40.76  ,  95.8525, 320.7385, 461.0635, 467.251 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_sleFreq), np.max(N2max_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_sleFreq[0]),float(N2max_sleFreq[1]),float(N2max_sleFreq[2]), float(N2max_sleFreq[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_sleFreq.jpg')
plt.show()

# %%
N2min_sleFreq = (27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+(11.36+18.48+91.476+46.2)+(0*9.64+0*2+.3*8+.3*59.40+.6*40+0*.552)
N2min_sleFreq
# Out:
# 455.371

# %%
N2min_sleFreq = NG1 + NG2 + np.array([0*9.64 + 0*2 + 0*.552, 0*9.64 + 0*2 + 0*.552 + .3*8, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40 + .6*40, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40 + .6*40])
N2min_sleFreq
# Out:
# array([ 40.76  ,  95.8525, 308.8585, 449.1835, 455.371 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_sleFreq), np.max(N2min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_sleFreq[0]),float(N2min_sleFreq[1]),float(N2min_sleFreq[2]),float(N2min_sleFreq[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_sleFreq.jpg')
plt.show()

# %% [markdown]
# ### SLE QUASI PERMANENTE

# %%
N2min_sleQP = (27.45+2*15+33.375+26.25+14.4+12.8+63.36+36)+(11.36+18.48+91.476+46.2)+(0*9.64+0*2+.3*8+.3*59.40+.6*40+0*.552)
N2min_sleQP
# Out:
# 455.371

# %%
N2_sleQP = NG1 + NG2 + np.array([0*9.64 + 0*2 + 0*.552, 0*9.64 + 0*2 + 0*.552 + .3*8, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40 + .6*40, 0*9.64 + 0*2 + 0*.552 + .3*8 + .3*59.40 + .6*40])
N2_sleQP
# Out:
# array([ 40.76  ,  95.8525, 308.8585, 449.1835, 455.371 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2_sleQP,s,12.2, color='#0f0f0f80')
plt.fill_between(N2_sleQP,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2_sleQP), np.max(N2min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2_sleQP[0]),float(N2_sleQP[1]),float(N2_sleQP[2]),float(N2_sleQP[4])])
plt.axhline(0, color='black')
plt.title('Azione assiale (di compressione) sul pilastro P36\nCombinazione SLE QUASI PERMANENTE', fontsize='22')
plt.savefig('export/img/P36_axialLoad_sleQP.jpg')
plt.show()

# %% [markdown]
# ---
