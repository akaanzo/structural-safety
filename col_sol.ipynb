# %% [markdown]
# # Columns Static Solution - Loads Combos
# ## *Matteo Franzoi* - Anno Accademico 2019/2020
# ### matricola 166788 (triennale)
# ---

# %%
    import math
#import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sympy import *
from sympy import MatrixSymbol, Matrix
import numpy as np
from engineering_notation import EngNumber
from decimal import Decimal
import pandas as pd

# %%
2.75+3.5+3.1+3.1-(.04+.16+.05)
# Out:
# 12.2

# %%
3.1-(.04+.16+.05)
# Out:
# 2.85

# %%
25*.3*.3*12.2
# Out:
# 27.45

# %% [markdown]
# ---
# ## P27
# ### SLU

# %%
N1max_slu = 1.3*(4*21.15+27.45+101.52+90.24+101.536+99.50)+1.5*(80.09+130.284+146.59+127.68)+1.5*(67.96+0*14.1+56.40+95.17+110.54+.6*3.9)
N1max_slu
# Out:
# 1881.8808000000001

# %%
N1min_slu = 1.0*(4*21.15+27.45+101.52+90.24+101.536+99.50)+.8*(80.09+130.284+146.59+127.68)+0*(67.96+0*14.1+.7*56.40+.7*95.17+.7*110.54)-1.5*3.9
N1min_slu
# Out:
# 886.7112000000001

# %%
l1 = 3.1 - .04 - .16 - .05
l2 = 3.1 
l3 = 3.5
l4 = 2.75

# %%
s = np.array([0,l1, l1, l1+l2, l1+l2, l1+l2+l3, l1+l2+l3, l1+l2+l3+l4])

# %%
NG1 = np.array([101.52+21.15, 101.52+21.15+25*.3**2 * l1, 101.52+21.15+90.24+21.15+25*.3**2 * l1, 101.52+3*21.15+90.24+25*.3**2 * (l1+l2), 101.52+3*21.15+90.24+25*.3**2 * (l1+l2) +101.536, 101.52+4*21.15+90.24+25*.3**2 * (l1+l2+l3) +101.536, 101.52+4*21.15+90.24+25*.3**2 * (l1+l2+l3) +101.536 + 99.50,  101.52+4*21.15+90.24+25*.3**2 * (l1+l2+l3+l4) +101.536 + 99.50])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NG1,s,12.2, color='#0f0f0f80')
# plt.fill_between(NG1,12.2,s, color='#0f0f0f80')
# plt.xlim(122, 507)
# plt.ylim(0, l1+l2+l3+l4)
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NG1(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NG1', fontsize='22')
# plt.show()

# %%
NG2 = np.array([80.09, 80.09, 80.09+130.284, 80.09+130.284, 80.09+130.284+146.59, 80.09+130.284+146.59, 80.09+130.284+146.59 + 127.68, 80.09+130.284+146.59 + 127.68])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NG2,s,12.2, color='#0f0f0f80')
# plt.fill_between(NG2,12.2,s, color='#0f0f0f80')
# plt.ylim(0, l1+l2+l3+l4)
# plt.xlim(np.min(NG2), np.max(NG2))
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NG2(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NG2', fontsize='22')
# plt.show()

# %%
NQ = np.array([67.96+0*14.1+.6*3.9, 67.96+0*14.1+.6*3.9, 67.96+0*14.1+56.40+.6*3.9, 67.96+0*14.1+56.40+.6*3.9, 67.96+0*14.1+.7*56.40+95.17+.6*3.9, 67.96+0*14.1+.7*56.40+95.17+.6*3.9, 67.96+0*14.1+56.40+95.17+110.54+.6*3.9, 67.96+0*14.1+56.40+95.17+110.54+.6*3.9])

# %% [raw]
# plt.figure(figsize=(20,10))
# plt.plot(NQ,s,12.2, color='#0f0f0f80')
# plt.fill_between(NQ,12.2,s, color='#0f0f0f80')
# plt.ylim(0, l1+l2+l3+l4)
# plt.xlim(np.min(NQ), np.max(NQ))
# plt.gca().invert_yaxis()
# plt.grid()
# plt.ylabel(r'$s\,[m]$', fontsize='14')
# plt.xlabel(r'$NQ(s)\,[kN]$', fontsize='14')
# plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
# plt.axhline(0, color='black')
# plt.title('NQ', fontsize='22')
# plt.show()

# %%
N1max_slu = 1.3*NG1 + 1.5*NG2 + 1.5*NQ
N1max_slu
# Out:
# array([ 385.056  ,  393.39225,  818.22525,  854.78775, 1324.04455,
#        1361.77705, 1873.83705, 1881.8808 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_slu), np.max(N1max_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_slu[0]),float(N1max_slu[3]), float(N1max_slu[5]), float(N1max_slu[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_slu.jpg')
plt.show()

# %%
N1min_slu = 1*NG1 + .8*NG2 + 0*NQ - 1.5*3.9
print(N1min_slu)
# Out:
# [180.892  187.3045 402.9217 431.0467 649.8547 678.8797 880.5237 886.7112]

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_slu), np.max(N1min_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_slu[0]),float(N1min_slu[3]), float(N1min_slu[5]), float(N1min_slu[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Aione assiale minima (di compressione) sul pilastro P27\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_slu.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE RARA

# %%
N1max_sleRara = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(67.96+0*14.1+56.40+95.17+110.54+.6*3.9)
N1max_sleRara
# Out:
# 1321.9

# %%
N1max_sleRara = NG1 + NG2 + NQ
N1max_sleRara
# Out:
# array([ 273.06  ,  279.4725,  577.5465,  605.6715,  932.0475,  961.0725,
#        1315.7125, 1321.9   ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_sleRara), np.max(N1max_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_sleRara[0]),float(N1max_sleRara[3]), float(N1max_sleRara[5]), float(N1max_sleRara[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_sleRara.jpg')
plt.show()

# %%
N1min_sleRara = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(.5*67.96+0*14.1+56.40+95.17+110.54-3.9)
N1min_sleRara
# Out:
# 1281.68

# %%
N1min_sleRara = NG1 + NG2 + np.array([.5*67.96+0*14.1-3.9, .5*67.96+0*14.1-3.9, .5*67.96+0*14.1+56.40-3.9, .5*67.96+0*14.1+56.40-3.9, .5*67.96+0*14.1+56.40+95.17-3.9, .5*67.96+0*14.1+56.40+95.17-3.9, .5*67.96+0*14.1+56.40+95.17+110.54-3.9, .5*67.96+0*14.1+56.40+95.17+110.54-3.9])
N1min_sleRara
# Out:
# array([ 232.84  ,  239.2525,  537.3265,  565.4515,  908.7475,  937.7725,
#        1275.4925, 1281.68  ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_sleRara), np.max(N1min_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_sleRara[0]), float(N1min_sleRara[3]), float(N1min_sleRara[5]), float(N1min_sleRara[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P27\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_sleRara.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE FREQUENTE

# %%
N1max_sleFreq = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(0.2*67.96+0*14.1+.5*56.40+.5*95.17+.7*110.54+0*3.9)
N1max_sleFreq
# Out:
# 1156.245

# %%
N1max_sleFreq = NG1 + NG2 + np.array([.2*67.96+0*14.1+0*3.9, .2*67.96+0*14.1+0*3.9, .2*67.96+0*14.1+0*3.9 +.5*56.40, .2*67.96+0*14.1+0*3.9 +.5*56.40,  .2*67.96+0*14.1+0*3.9 +.5*56.40+.5*95.17, .2*67.96+0*14.1+0*3.9 +.5*56.40+.5*95.17, .2*67.96+0*14.1+0*3.9 +.5*56.40+.5*95.17+.7*110.54, .2*67.96+0*14.1+0*3.9 +.5*56.40+.5*95.17+.7*110.54])
np.max(N1max_sleFreq)
# Out:
# 1156.245

# %%
plt.figure(figsize=(20,10))
plt.plot(N1max_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N1max_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1max_sleFreq), np.max(N1max_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1max_sleFreq[0]),float(N1max_sleFreq[3]), float(N1max_sleFreq[5]), float(N1max_sleFreq[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P27\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P27_maxAxialLoad_sleFreq.jpg')
plt.show()

# %%
N1min_sleFreq = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54-0.2*3.9)
N1min_sleFreq
# Out:
# 1100.505

# %%
N1min_sleFreq = NG1 + NG2 + np.array([0*67.96+0*14.1-0.2*3.9, 0*67.96+0*14.1-0.2*3.9, 0*67.96+0*14.1-0.2*3.9 +.3*56.40, 0*67.96+0*14.1-0.2*3.9 +.3*56.40,  0*67.96+0*14.1-0.2*3.9 +.3*56.40+.5*95.17, 0*67.96+0*14.1-0.2*3.9 +.3*56.40+.3*95.17, 0*67.96+0*14.1-0.2*3.9 +.3*56.40+.3*95.17+.6*110.54, 0*67.96+0*14.1-0.2*3.9 +.3*56.40+.3*95.17+.6*110.54])
N1min_sleFreq
# Out:
# array([ 201.98  ,  208.3925,  466.9865,  495.1115,  790.8225,  800.8135,
#        1094.3175, 1100.505 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N1min_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N1min_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1min_sleFreq), np.max(N1min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1min_sleFreq[0]),float(N1min_sleFreq[3]), float(N1min_sleFreq[5]), float(N1min_sleFreq[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P27\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P27_minAxialLoad_sleFreq.jpg')
plt.show()

# %% [markdown]
# ---
# ### SLE QUASI PERMANENTE

# %%
N1_sleQP = (4*21.15+27.45+101.52+90.24+101.536+99.50)+(80.09+130.284+146.59+127.68)+(0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9)
N1_sleQP
# Out:
# 1101.285

# %%
N1_sleQP = NG1 + NG2 +  np.array([0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+0*3.9, 0*67.96+0*14.1+.3*56.40+0*3.9, 0*67.96+0*14.1+.3*56.40+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9, 0*67.96+0*14.1+.3*56.40+.3*95.17+.6*110.54+0*3.9])
np.max(N1_sleQP)
# Out:
# 1101.285

# %%
plt.figure(figsize=(20,10))
plt.plot(N1_sleQP,s,12.2, color='#0f0f0f80')
plt.fill_between(N1_sleQP,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N1_sleQP), np.max(N1_sleQP))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N1_sleQP[0]), float(N1_sleQP[3]), float(N1_sleQP[5]), float(N1_sleQP[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale (di compressione) sul pilastro P27\nCombinazione SLE QUASI PERMANENTE', fontsize='22')
plt.savefig('export/img/P27_axialLoad_sleQP.jpg')
plt.show()

# %% [markdown]
# ---
# ## P36
# ### SLU

# %%
N2max_slu = 1.3*(27.45 + 15 +10.8 + 15+9.60 + 33.375+9.60+52.80+72+26.25)+1.5*(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+1.5*(7.23+0*1.5+.6*.414+6+.7*9+.7*66+80.85+.6*2.28+80)
N2max_slu
# Out:
# 1067.1171

# %%
NG1 = np.array([15 + 10.8, 15 + 10.8+ 25*.3**2 * l1, 15 + 10.8+15+9.6+ 25*.3**2 * l1, 15 + 10.8+15+9.60 +25*.3**2 * (l1+l2), 10.8+15+9.60+33.375+9.6+52.80 +25*.3**2 * (l1+l2), 15 + 10.8+15+9.60+33.375+9.60+52.80+25*.3**2 * (l1+l2+l3), 15 + 10.8+15+9.60+33.375+9.60+ 52.80+72+26.25+25*.3**2 * (l1+l2+l3), 15 + 10.8+15+9.60+33.375+9.60+52.80+72+26.25+25*.3**2 * (l1+l2+l3+l4)])

NG2 = np.array([8.52, 8.52, 8.52+13.86+41.92,8.52+13.86+41.92, 8.52+13.86+41.92+13.86+36.55+40.48, 8.52+13.86+41.92+13.86+36.55+40.48, 8.52+13.86+41.92+13.86+36.55+40.48+92.40, 8.52+13.86+41.92+13.86+36.55+40.48+92.40])

NQ = np.array([7.23+0*1.5+.6*.414, 7.23+0*1.5+.6*.414, 7.23+0*1.5+.6*.414 + 6, 7.23+0*1.5+.6*.414 + 6, 7.23+0*1.5+.6*.414 + 6 + .7*9+.7*66+80.85+.6*2.28, 7.23+0*1.5+.6*.414 + 6 + .7*9+.7*66+80.85+.6*2.28, 7.23+0*1.5+.6*.414 + 6 + .7*9+.7*66+80.85+.6*2.28 + 80, 7.23+0*1.5+.6*.414 + 6 + .7*9+.7*66+80.85+.6*2.28 + 80])

# %%
N2max_slu = 1.3*NG1 + 1.5*NG2 + 1.5*NQ
N2max_slu
# Out:
# array([  57.5376 ,   65.87385,  190.52385,  199.59135,  643.01085,
#         672.74835, 1059.07335, 1067.1171 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_slu), np.max(N2max_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_slu[0]),float(N2max_slu[3]), float(N2max_slu[5]), float(N2max_slu[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_slu.jpg')
plt.show()

# %%
N2min_slu = 1*NG1 + 0.8*NG2 + 0*NQ -1.5*np.array([.414, .414, .414, .414, .414+2.28, .414+2.28, .414+2.28, .414+2.28])
N2min_slu
# Out:
# array([ 31.995 ,  38.4075, 107.6315, 114.6065, 264.6735, 287.5485,
#        459.7185, 465.906 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_slu,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_slu,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_slu), np.max(N2min_slu))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_slu[0]),float(N2min_slu[3]),float(N2min_slu[5]), float(N2min_slu[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLU', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_slu.jpg')
plt.show()

# %% [markdown]
# ### SLE RARA

# %%
N2max_sleRara = (27.45 + 15+10.8 + 15+9.60 + 33.375+9.60+52.80 +72+26.25)+(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+(7.23+0*1.5+.6*.414+.6+.7*9+.7*66+80.85+.6*2.28+80)
N2max_sleRara
# Out:
# 742.2614

# %%
N2max_sleRara = NG1 + NG2 + NQ
N2max_sleRara
# Out:
# array([ 41.7984,  48.2109, 134.5909, 141.5659, 447.9489, 470.8239,
#        741.4739, 747.6614])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_sleRara), np.max(N2max_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_sleRara[0]),float(N2max_sleRara[3]), float(N2max_sleRara[5]), float(N2max_sleRara[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_sleRara.jpg')
plt.show()

# %%
N2min_sleRara = (27.45 + 15+10.8 + 15+9.60 + 33.375+9.60+52.80+72+26.25)+(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+(.5*7.23+0*1.5+.414+6+.7*9+.7*66+.5*80.85+2.28+80)
N2min_sleRara
# Out:
# 704.6990000000001

# %%
N2min_sleRara = NG1 + NG2 + np.array([.5*7.23+0*1.5+.414, .5*7.23+0*1.5+.414, .5*7.23+0*1.5+.414 + 6, .5*7.23+0*1.5+.414 + 6, .5*7.23+0*1.5+.414 + 6 + .7*9+.7*66+.5*80.85+2.28, 7.5*.23+0*1.5+.414 + 6 + .7*9+.7*66+.5*80.85+2.28, .5*7.23+0*1.5+.414 +6 + .7*9+.7*66+.5*80.85+2.28 + 80, .5*7.23+0*1.5+.414 + 6 + .7*9+.7*66+.5*80.85+2.28 + 80])
N2min_sleRara
# Out:
# array([ 38.349 ,  44.7615, 131.1415, 138.1165, 404.9865, 425.9715,
#        698.5115, 704.699 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_sleRara,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_sleRara,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_sleRara), np.max(N2min_sleRara))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_sleRara[0]),float(N2min_sleRara[3]),float(N2min_sleRara[5]),float(N2min_sleRara[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLE RARA', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_sleRara.jpg')
plt.show()

# %% [markdown]
# ### SLE FREQUENTE

# %%
N2max_sleFreq = (27.45 + 15+10.8 + 15+9.60 + 33.375+9.60+52.80 +72+26.25)+(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+(.2*7.23+0*1.5+0*.414+.3*6+.3*9+.3*66+.2*80.85+0*2.28+.6*80)
N2max_sleFreq
# Out:
# 609.3810000000001

# %%
N2max_sleFreq = NG1 + NG2 + np.array([.2*7.23+0*1.5+0*.414, .2*7.23+0*1.5+0*.414, .2*7.23+0*1.5+0*.414 + .3*6, .2*7.23+0*1.5+0*.414 + .3*6, .2*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+.2*80.85+0*2.28, .2*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+.2*80.85+0*2.28, .2*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+.2*80.85+0*2.28 + .6*80, .2*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+.2*80.85+0*2.28+.6*80])
N2max_sleFreq
# Out:
# array([ 35.766 ,  42.1785, 124.3585, 131.3335, 341.6685, 364.5435,
#        603.1935, 609.381 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2max_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N2max_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2max_sleFreq), np.max(N2max_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2max_sleFreq[0]),float(N2max_sleFreq[3]),float(N2max_sleFreq[5]), float(N2max_sleFreq[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale massima (di compressione) sul pilastro P36\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P36_maxAxialLoad_sleFreq.jpg')
plt.show()

# %%
N2min_sleFreq = (27.45 + 15+10.8 + 15+9.60 + 33.375+9.60+52.80 +72+26.25)+(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+(0*7.23+0*1.5+.2*.414+.3*6+.3*9+.3*66+0*80.85+.2*2.28+.6*80)
N2min_sleFreq
# Out:
# 592.3038

# %%
N2min_sleFreq = NG1 + NG2 + np.array([0*7.23+0*1.5+.2*.414, 0*7.23+0*1.5+.2*.414, 0*7.23+0*1.5+.2*.414 + .3*6, 0*7.23+0*1.5+.2*.414 + .3*6, 0*7.23+0*1.5+.2*.414 + .3*6 + .3*9+.3*66+0*80.85+0.2*2.28, 0*7.23+0*1.5+.2*.414 + .3*6 + .3*9+.3*66+0*80.85+0.2*2.28, 0*7.23+0*1.5+.2*.414 + .3*6 + .3*9+.3*66+0*80.85+.2*2.28+.6*80, 0*7.23+0*1.5+.2*.414 + .3*6 + .3*9+.3*66+0*80.85+.2*2.28 + .6*80])
N2min_sleFreq
# Out:
# array([ 34.4028,  40.8153, 122.9953, 129.9703, 324.5913, 347.4663,
#        586.1163, 592.3038])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2min_sleFreq,s,12.2, color='#0f0f0f80')
plt.fill_between(N2min_sleFreq,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2min_sleFreq), np.max(N2min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2min_sleFreq[0]),float(N2min_sleFreq[3]),float(N2min_sleFreq[5]),float(N2min_sleFreq[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale minima (di compressione) sul pilastro P36\nCombinazione SLE FREQUENTE', fontsize='22')
plt.savefig('export/img/P36_minAxialLoad_sleFreq.jpg')
plt.show()

# %% [markdown]
# ### SLE QUASI PERMANENTE

# %%
N2min_sleQP = (27.45 + 15+10.8 + 15+9.60 + 33.375+9.60+52.80 +72+26.25)+(8.52+13.86+41.92+13.86+36.55+40.48+92.40)+(0*7.23+0*1.5+0*.414+.3*6+.3*9+.3*66+0*80.85+0*2.28+.6*80)
N2min_sleQP
# Out:
# 591.765

# %%
N2_sleQP = NG1 + NG2 + np.array([0*7.23+0*1.5+0*.414, 0*7.23+0*1.5+0*.414, 0*7.23+0*1.5+0*.414 + .3*6, 0*7.23+0*1.5+.0*.414 + .3*6, 0*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+0*80.85+0*2.28, 0*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+0*80.85+0.2*28, 0*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+0*80.85+0*2.28+.6*80, 0*7.23+0*1.5+0*.414 + .3*6 + .3*9+.3*66+0*80.85+0*2.28 + .6*80])
N2_sleQP
# Out:
# array([ 34.32  ,  40.7325, 122.9125, 129.8875, 324.0525, 352.5275,
#        585.5775, 591.765 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(N2_sleQP,s,12.2, color='#0f0f0f80')
plt.fill_between(N2_sleQP,12.2,s, color='#0f0f0f80')
plt.ylim(0, l1+l2+l3+l4)
plt.xlim(np.min(N2_sleQP), np.max(N2min_sleFreq))
plt.gca().invert_yaxis()
plt.grid()
plt.ylabel(r'$s\,[m]$', fontsize='14')
plt.xlabel(r'$N(s)\,[kN]$', fontsize='14')
plt.yticks([0,l1, l1+l2, l1+l2+l3, l1+l2+l3+l4])
plt.xticks([float(N2_sleQP[0]),float(N2_sleQP[3]),float(N2_sleQP[5]),float(N2_sleQP[7])])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axhline(0, color='black')
plt.title('Azione assiale (di compressione) sul pilastro P36\nCombinazione SLE QUASI PERMANENTE', fontsize='22')
plt.savefig('export/img/P36_axialLoad_sleQP.jpg')
plt.show()

# %% [markdown]
# ---
